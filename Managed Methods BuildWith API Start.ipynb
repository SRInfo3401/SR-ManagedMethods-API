# %% [markdown]
# ## Steven Rothaus - BuildWith API Pratice(FREE)
# #### Notes other BuiltWith API's and Features-https://docs.google.com/document/d/1s6KOkm2JRgBU8WrWkIT7jRgO7bWFY954guiasY_EKcM/edit#
# #### The Free API will respond with a document in the format -result->groups[group->categories[category]]
# #### JSON can be worked with as native objects, once parsed its easier to work coding. XML format is about 38% shorter in lines of code, while being more readable.
# #### Call/Recieve content of URL parse it as JSON and return object.
# #### Call to urlopen() returns a file object. After return, call read() method to complete JSON data pull.

# %%
#Required Imports
import pandas as pd
import numpy as np
import json
import urllib.request
#Data Visualization Tools
#import matplotlib.pyplot as plt
#import seaborn as sb

#BuildWith API with my key. 
##https://api.builtwith.com/free1/api.json?KEY=2cb7b958-c54c-465a-bd0e-a4e05774023e&LOOKUP=builtwith.com

# %%
#Most efficient API Json Pull. With df label.
# Call BuiltWith API
# Try new URL (University Hill Elementary School)

BuildWith_API_data = urllib.request.urlopen("https://api.builtwith.com/free1/api.json?KEY=2cb7b958-c54c-465a-bd0e-a4e05774023e&LOOKUP=builtwith.com").read()
site_data_output = json.loads(BuildWith_API_data)
site_data_output
#print(site_data_output)
# Out:
# {'first': 1294059600,
#  'last': 1553554800,
#  'domain': 'builtwith.com',
#  'groups': [{'name': 'payment',
#    'live': 0,
#    'dead': 5,
#    'latest': 1492556400,
#    'oldest': 1343570400,
#    'categories': [{'live': 0,
#      'dead': 1,
#      'latest': 1369922400,
#      'oldest': 1343570400,
#      'name': 'payments-processor'},
#     {'live': 0,
#      'dead': 4,
#      'latest': 1492556400,
#      'oldest': 1458738000,
#      'name': 'payment-acceptance'}]},
#   {'name': 'ssl',
#    'live': 3,
#    'dead': 8,
#    'latest': 1553554800,
#    'oldest': 1372806000,
#    'categories': [{'live': 0,
#      'dead': 1,
#      'latest': 1545951600,
#      'oldest': 1476831600,
#      'name': 'multi-domain'},
#     {'live': 1,
#      'dead': 1,
#      'latest': 1553554800,
#      'oldest': 1452303436,
#      'name': 'extended-validation'},
#     {'live': 1,
#      'dead': 4,
#      'latest': 1553554800,
#      'oldest': 1372806000,
#      'name': 'root-authority'},
# ...

# %%
test_API_df_first = pd.DataFrame.from_dict(site_data_output, orient='columns')
test_API_df_first
# Out:
#          first        last         domain  \
# 0   1294059600  1553554800  builtwith.com
# 1   1294059600  1553554800  builtwith.com
# 2   1294059600  1553554800  builtwith.com
# 3   1294059600  1553554800  builtwith.com
# 4   1294059600  1553554800  builtwith.com
# 5   1294059600  1553554800  builtwith.com
# 6   1294059600  1553554800  builtwith.com
# 7   1294059600  1553554800  builtwith.com
# 8   1294059600  1553554800  builtwith.com
# 9   1294059600  1553554800  builtwith.com
# 10  1294059600  1553554800  builtwith.com
# 11  1294059600  1553554800  builtwith.com
# 12  1294059600  1553554800  builtwith.com
# 13  1294059600  1553554800  builtwith.com
# 14  1294059600  1553554800  builtwith.com
# 15  1294059600  1553554800  builtwith.com
# 16  1294059600  1553554800  builtwith.com
# 17  1294059600  1553554800  builtwith.com
# 18  1294059600  1553554800  builtwith.com
# 19  1294059600  1553554800  builtwith.com
# 20  1294059600  1553554800  builtwith.com
# ...

# %%
#Little bit of manual cleaning. (Groups DF)
##format dataframe single row x columns (data = [{'x': y,'x1': y1,'x2': y2,'x3': y3,...}]
##format x rows x columns (data = [{'x': y,'x1': y1},{'z': 'n','z1' : 'n1'},...{}]
builtwith_manual_df = [{'live': 0, 'dead': 1, 'latest': 1369922400, 'oldest': 1343570400, 'name': 'payments-processor'}, {'live': 0, 'dead': 4, 'latest': 1492556400, 'oldest': 1458738000, 'name': 'payment-acceptance'}, {'name': 'ssl', 'live': 3, 'dead': 8, 'latest': 1553554800, 'oldest': 1372806000}, {'live': 0, 'dead': 1, 'latest': 1545951600, 'oldest': 1476831600, 'name': 'multi-domain'}, {'live': 1, 'dead': 1, 'latest': 1553554800, 'oldest': 1452303436, 'name': 'extended-validation'}, {'live': 1, 'dead': 4, 'latest': 1553554800, 'oldest': 1372806000, 'name': 'root-authority'}, {'live': 0, 'dead': 1, 'latest': 1476745200, 'oldest': 1372806000, 'name': 'wildcard'}, {'name': 'ads', 'live': 2, 'dead': 2, 'latest': 1551567600, 'oldest': 1343570400}, {'live': 0, 'dead': 1, 'latest': 1348668000, 'oldest': 1343570400, 'name': 'ad-network'}, {'live': 0, 'dead': 1, 'latest': 1348668000, 'oldest': 1343570400, 'name': 'facebook-exchange'}, {'live': 1, 'dead': 1, 'latest': 1551567600, 'oldest': 1343570400, 'name': 'retargeting-/-remarketing'}, {'live': 0, 'dead': 1, 'latest': 1369922400, 'oldest': 1343570400, 'name': 'contextual-advertising'}, {'name': 'analytics', 'live': 3, 'dead': 8, 'latest': 1553554800, 'oldest': 1294059600}, {'live': 1, 'dead': 1, 'latest': 1551567600, 'oldest': 1448582400, 'name': 'conversion-optimization'}, {'live': 0, 'dead': 1, 'latest': 1514242800, 'oldest': 1448582400, 'name': 'a/b-testing'}, {'live': 0, 'dead': 1, 'latest': 1514242800, 'oldest': 1448582400, 'name': 'personalization'}, {'live': 0, 'dead': 1, 'latest': 1514242800, 'oldest': 1448582400, 'name': 'site-optimization'}, {'live': 0, 'dead': 1, 'latest': 1487545200, 'oldest': 1458738000, 'name': 'marketing-automation'}, {'live': 0, 'dead': 1, 'latest': 1476745200, 'oldest': 1393974328, 'name': 'social-management'}, {'live': 1, 'dead': 0, 'latest': 1553554800, 'oldest': 1430886633, 'name': 'application-performance'}, {'live': 1, 'dead': 0, 'latest': 1553554800, 'oldest': 1430886633, 'name': 'audience-measurement'}, {'live': 1, 'dead': 0, 'latest': 1553554800, 'oldest': 1430886633, 'name': 'visitor-count-tracking'}, {'live': 0, 'dead': 1, 'latest': 1453879729, 'oldest': 1453879729, 'name': 'fraud-prevention'}, {'name': 'framework', 'live': 5, 'dead': 2, 'latest': 1551567600, 'oldest': 1378422000},{'live': 2, 'dead': 0, 'latest': 1551567600, 'oldest': 1395356400, 'name': 'wordpress-theme'}, {'live': 2, 'dead': 0, 'latest': 1551567600, 'oldest': 1378422000, 'name': 'programming-language'}, {'name': 'mapping', 'live': 0, 'dead': 2, 'latest': 1512082800, 'oldest': 1380236400}, {'live': 0, 'dead': 1, 'latest': 1512082800, 'oldest': 1380236400, 'name': 'maps'}, {'name': 'cms', 'live': 3, 'dead': 18, 'latest': 1551567600, 'oldest': 1324213200},{'live': 0, 'dead': 1, 'latest': 1399186286, 'oldest': 1380236400, 'name': 'financial'}, {'live': 0, 'dead': 1, 'latest': 1437217946, 'oldest': 1430179200, 'name': 'enterprise'}, {'live': 1, 'dead': 1, 'latest': 1551567600, 'oldest': 1324213200, 'name': 'open-source'}, {'live': 1, 'dead': 2, 'latest': 1551567600, 'oldest': 1324213200, 'name': 'blog'}, {'name': 'widgets', 'live': 4, 'dead': 18, 'latest': 1553554800, 'oldest': 1294059600}, {'live': 2, 'dead': 3, 'latest': 1551567600, 'oldest': 1394409954, 'name': 'wordpress-plugins'}, {'live': 1, 'dead': 3, 'latest': 1551567600, 'oldest': 1450450710, 'name': 'image-provider'}, {'live': 0, 'dead': 2, 'latest': 1370559600, 'oldest': 1294059600, 'name': 'feedback-forms-and-surveys'}, {'live': 0, 'dead': 1, 'latest': 1530572400, 'oldest': 1390274100, 'name': 'charting'}, {'live': 0, 'dead': 1, 'latest': 1430556570, 'oldest': 1393974328, 'name': 'social-sharing'}, {'live': 0, 'dead': 2, 'latest': 1530572400, 'oldest': 1401853197, 'name': 'site-search'}, {'live': 1, 'dead': 1, 'latest': 1553554800, 'oldest': 1522710000, 'name': 'fonts'}, {'name': 'javascript', 'live': 10, 'dead': 35, 'latest': 1553554800, 'oldest': 1304344800}, {'live': 0, 'dead': 2, 'latest': 1479942000, 'oldest': 1388957967, 'name': 'social-sdk'}, {'live': 0, 'dead': 3, 'latest': 1517922000, 'oldest': 1324213200, 'name': 'lightbox'}, {'live': 1, 'dead': 9, 'latest': 1551567600, 'oldest': 1343570400, 'name': 'jquery-plugin'}, {'live': 0, 'dead': 2, 'latest': 1530572400, 'oldest': 1384297200, 'name': 'animation'}, {'live': 2, 'dead': 2, 'latest': 1553554800, 'oldest': 1343570400, 'name': 'javascript-library'}, {'live': 1, 'dead': 2, 'latest': 1551567600, 'oldest': 1387148400, 'name': 'compatibility'}, {'live': 0, 'dead': 1, 'latest': 1442250626, 'oldest': 1389567600, 'name': 'cookie-management'}, {'live': 0, 'dead': 2, 'latest': 1476572400, 'oldest': 1324213200, 'name': 'media'}, {'live': 0, 'dead': 3, 'latest': 1531436400, 'oldest': 1364302800, 'name': 'ui'}, {'live': 1, 'dead': 1, 'latest': 1551567600, 'oldest': 1505084400, 'name': 'forms-and-surveys'}, {'live': 0, 'dead': 1, 'latest': 1530572400, 'oldest': 1509490800, 'name': 'charting'}, {'live': 1, 'dead': 0, 'latest': 1553554800, 'oldest': 1530831600, 'name': 'framework'}, {'name': 'media', 'live': 0, 'dead': 2, 'latest': 1510009200, 'oldest': 1459551600}, {'live': 0, 'dead': 2, 'latest': 1510009200, 'oldest': 1459551600, 'name': 'video-players'}, {'live': 0, 'dead': 1, 'latest': 1461625200, 'oldest': 1459551600, 'name': 'online-video-platform'}, {'name': 'mobile', 'live': 3, 'dead': 2, 'latest': 1553554800, 'oldest': 1415587208}, {'name': 'Web Master', 'live': 0, 'dead': 4, 'latest': 1518735600, 'oldest': 1294059600}, {'name': 'shop', 'live': 0, 'dead': 1, 'latest': 1545951600, 'oldest': 1527721200}, {'live': 0, 'dead': 1, 'latest': 1545951600, 'oldest': 1527721200, 'name': 'non-platform'}, {'name': 'Web Server', 'live': 4, 'dead': 4, 'latest': 1553554800, 'oldest': 1294059600}, {'live': 2, 'dead': 2, 'latest': 1553554800, 'oldest': 1294059600, 'name': 'windows-web-server'}, {'name': 'hosting', 'live': 2, 'dead': 3, 'latest': 1553554800, 'oldest': 1345730400}, {'live': 1, 'dead': 0, 'latest': 1551567600, 'oldest': 1379286000, 'name': 'vps-hosting'}, {'live': 1, 'dead': 0, 'latest': 1551567600, 'oldest': 1379286000, 'name': 'us-hosting'}, {'live': 1, 'dead': 1, 'latest': 1553554800, 'oldest': 1345730400, 'name': 'dedicated-hosting'}, {'live': 0, 'dead': 1, 'latest': 1376866800, 'oldest': 1345730400, 'name': 'german-hosting'}, {'live': 1, 'dead': 0, 'latest': 1553554800, 'oldest': 1389222000, 'name': 'canadian-hosting'}, {'live': 1, 'dead': 0, 'latest': 1553554800, 'oldest': 1389222000, 'name': 'french-hosting'}, {'live': 0, 'dead': 1, 'latest': 1531436400, 'oldest': 1402012800, 'name': 'cloud-hosting'}, {'live': 0, 'dead': 1, 'latest': 1531436400, 'oldest': 1402012800, 'name': 'cloud-paas'}, {'name': 'cdn', 'live': 5, 'dead': 2, 'latest': 1553554800, 'oldest': 1364302800}, {'name': 'feeds', 'live': 4, 'dead': 1, 'latest': 1551567600, 'oldest': 1294059600}, {'name': 'Server', 'live': 1, 'dead': 0, 'latest': 1551567600, 'oldest': 1324213200}, {'name': 'copyright', 'live': 0, 'dead': 2, 'latest': 1531436400, 'oldest': 1488582000}, {'name': 'cdns', 'live': 2, 'dead': 0, 'latest': 1553554800, 'oldest': 1386284400},{'live': 1, 'dead': 0, 'latest': 1551567600, 'oldest': 1386284400, 'name': 'edge-delivery-network'}, {'name': 'ns', 'live': 1, 'dead': 1, 'latest': 1553554800, 'oldest': 1346972400}, {'live': 1, 'dead': 0, 'latest': 1553554800, 'oldest': 1370905200, 'name': 'enterprise-dns'}, {'name': 'mx', 'live': 5, 'dead': 3, 'latest': 1553554800, 'oldest': 1315749600}, {'live': 1, 'dead': 0, 'latest': 1553554800, 'oldest': 1364302800, 'name': 'crm'}, {'live': 1, 'dead': 0, 'latest': 1553554800, 'oldest': 1364302800, 'name': 'ticketing-system'}, {'live': 0, 'dead': 1, 'latest': 1369922400, 'oldest': 1346940000, 'name': 'web-hosting-provider-email'}, {'live': 0, 'dead': 1, 'latest': 1412563029, 'oldest': 1344520800, 'name': 'campaign-management'}, {'live': 2, 'dead': 0, 'latest': 1553554800, 'oldest': 1344520800, 'name': 'transactional-email'}, {'live': 1, 'dead': 0, 'latest': 1553554800, 'oldest': 1315749600, 'name': 'business-email-hosting'}, {'live': 1, 'dead': 1, 'latest': 1553554800, 'oldest': 1397084400, 'name': 'standard'}, {'name': 'CDN', 'live': 1, 'dead': 0, 'latest': 1553554800, 'oldest': 1294059600}, {'name': 'css', 'live': 2, 'dead': 3, 'latest': 1553554800, 'oldest': 1414018800}, {'name': 'link', 'live': 1, 'dead': 0, 'latest': 1551481200, 'oldest': 1537138800}, {'live': 1, 'dead': 0, 'latest': 1551481200, 'oldest': 1537138800, 'name': 'homepage-link'}]
builtwith_groups_df_manual = pd.DataFrame.from_dict(builtwith_manual_df, orient='columns')
builtwith_groups_df_manual
# Out:
#     dead      latest  live                        name      oldest
# 0      1  1369922400     0          payments-processor  1343570400
# 1      4  1492556400     0          payment-acceptance  1458738000
# 2      8  1553554800     3                         ssl  1372806000
# 3      1  1545951600     0                multi-domain  1476831600
# 4      1  1553554800     1         extended-validation  1452303436
# 5      4  1553554800     1              root-authority  1372806000
# 6      1  1476745200     0                    wildcard  1372806000
# 7      2  1551567600     2                         ads  1343570400
# 8      1  1348668000     0                  ad-network  1343570400
# 9      1  1348668000     0           facebook-exchange  1343570400
# 10     1  1551567600     1   retargeting-/-remarketing  1343570400
# 11     1  1369922400     0      contextual-advertising  1343570400
# 12     8  1553554800     3                   analytics  1294059600
# ...

# %% [markdown]
# ### DataFrame Column Metric Notes
# #### Results:
# #### Name	Example	Description
# #### domain	hotelscombined.com	The domain that was looked up.
# #### groups	The group of tags explained below	Explained below.
# #### first	1294059600	Epoch time the domain was first ever indexed
# #### last	1501282800	Epoch time the domain was last indexed
#
# #### Groups:
# #### name	javascript	The tag name - see all here
# #### live	8	Technologies in this group which are considered live on the domain.
# #### dead	4	Technologies in this group which are considered no longer live on the domain.
# #### latest	1479942000	The most recent date of a technology indexed in this group found on the website
# #### oldest	1388957967	The earliest date of a technology indexed in this group on the website
# #### categories	The categories within this group explained below	Explained below.

# %%
#Check Data Trypes (Domain:Cluster Groups)
test_API_df_first.dtypes
# Out:
# first      int64
# last       int64
# domain    object
# groups    object
# dtype: object

# %%
#Check Data Trypes (Cluster Section)
builtwith_groups_df_manual.dtypes
# Out:
# dead       int64
# latest     int64
# live       int64
# name      object
# oldest     int64
# dtype: object

# %%
#Clean/Sort/Combine Dataframes (Try to set to copper/outreach format)
test_API_df_first.head(5)
# Out:
#         first        last         domain  \
# 0  1294059600  1553554800  builtwith.com
# 1  1294059600  1553554800  builtwith.com
# 2  1294059600  1553554800  builtwith.com
# 3  1294059600  1553554800  builtwith.com
# 4  1294059600  1553554800  builtwith.com
#
#                                               groups
# 0  {'name': 'payment', 'live': 0, 'dead': 5, 'lat...
# 1  {'name': 'ssl', 'live': 3, 'dead': 8, 'latest'...
# 2  {'name': 'ads', 'live': 2, 'dead': 2, 'latest'...
# 3  {'name': 'analytics', 'live': 3, 'dead': 8, 'l...
# 4  {'name': 'framework', 'live': 5, 'dead': 2, 'l...

# %%
#Check if data is all there/are some clustered together here in categories?
test_API_df_first.domain.value_counts()
# Out:
# builtwith.com    26
# Name: domain, dtype: int64

# %%
#Clean/Sort/Combine(Append/Pivot table) Dataframes (Try to set to copper/outreach format)
builtwith_groups_df_manual.head(5)
# Out:
#    dead      latest  live                 name      oldest
# 0     1  1369922400     0   payments-processor  1343570400
# 1     4  1492556400     0   payment-acceptance  1458738000
# 2     8  1553554800     3                  ssl  1372806000
# 3     1  1545951600     0         multi-domain  1476831600
# 4     1  1553554800     1  extended-validation  1452303436

# %%
len(builtwith_groups_df_manual)
# Out:
# 92

# %%
#Any duplicates?
builtwith_groups_df_manual.name.value_counts().head()
# Out:
# media        2
# framework    2
# charting     2
# wildcard     1
# maps         1
# Name: name, dtype: int64

# %%
#Clean/Sort Dataframe (Try to set to copper/outreach format)
bw_order_df = builtwith_groups_df_manual.reindex(['name','live','dead','latest','oldest'], axis=1)

# %%
#How to target priority customers.
#Sort to see top live and dead scripts on domain.
##Can sort by 1 or x amount of columns (single = by='',)
bw_df_sort = bw_order_df.sort_values(by=['live','dead'], ascending=False)
bw_df_sort
# Out:
#                           name  live  dead      latest      oldest
# 41                  javascript    10    35  1553554800  1304344800
# 80                          mx     5     3  1553554800  1315749600
# 23                   framework     5     2  1551567600  1378422000
# 72                         cdn     5     2  1553554800  1364302800
# 33                     widgets     4    18  1553554800  1294059600
# 61                  Web Server     4     4  1553554800  1294059600
# 73                       feeds     4     1  1551567600  1294059600
# 28                         cms     3    18  1551567600  1324213200
# 2                          ssl     3     8  1553554800  1372806000
# 12                   analytics     3     8  1553554800  1294059600
# 57                      mobile     3     2  1553554800  1415587208
# 34           wordpress-plugins     2     3  1551567600  1394409954
# 63                     hosting     2     3  1553554800  1345730400
# ...

# %%
#Focus on duplicates or target customers(can do range)
bw_focus_df_example = bw_df_sort.query("name == 'media'")
bw_focus_df_example
# Out:
#      name  live  dead      latest      oldest
# 49  media     0     2  1476572400  1324213200
# 54  media     0     2  1510009200  1459551600

# %%
#Combine(Append/Pivot table) Dataframes (Domain/First Last)
builtwith_API_final_df = bw_df_sort.join(test_API_df_first)
builtwith_API_final_df
# Out:
#                           name  live  dead      latest      oldest  \
# 41                  javascript    10    35  1553554800  1304344800
# 80                          mx     5     3  1553554800  1315749600
# 23                   framework     5     2  1551567600  1378422000
# 72                         cdn     5     2  1553554800  1364302800
# 33                     widgets     4    18  1553554800  1294059600
# 61                  Web Server     4     4  1553554800  1294059600
# 73                       feeds     4     1  1551567600  1294059600
# 28                         cms     3    18  1551567600  1324213200
# 2                          ssl     3     8  1553554800  1372806000
# 12                   analytics     3     8  1553554800  1294059600
# 57                      mobile     3     2  1553554800  1415587208
# 34           wordpress-plugins     2     3  1551567600  1394409954
# 63                     hosting     2     3  1553554800  1345730400
# ...

# %%
#builtwith_API_final_df.fillna(method='bfill')
data_fill = builtwith_API_final_df.fillna(method='ffill')
data_fill
# Out:
#                           name  live  dead      latest      oldest  \
# 41                  javascript    10    35  1553554800  1304344800
# 80                          mx     5     3  1553554800  1315749600
# 23                   framework     5     2  1551567600  1378422000
# 72                         cdn     5     2  1553554800  1364302800
# 33                     widgets     4    18  1553554800  1294059600
# 61                  Web Server     4     4  1553554800  1294059600
# 73                       feeds     4     1  1551567600  1294059600
# 28                         cms     3    18  1551567600  1324213200
# 2                          ssl     3     8  1553554800  1372806000
# 12                   analytics     3     8  1553554800  1294059600
# 57                      mobile     3     2  1553554800  1415587208
# 34           wordpress-plugins     2     3  1551567600  1394409954
# 63                     hosting     2     3  1553554800  1345730400
# ...

# %%
#Usefull or should Javascript and MX be seperate from css group.
data_filled = fill.fillna(method='bfill')
data_filled
# Out:
#                           name  live  dead      latest      oldest  \
# 41                  javascript    10    35  1553554800  1304344800
# 80                          mx     5     3  1553554800  1315749600
# 23                   framework     5     2  1551567600  1378422000
# 72                         cdn     5     2  1553554800  1364302800
# 33                     widgets     4    18  1553554800  1294059600
# 61                  Web Server     4     4  1553554800  1294059600
# 73                       feeds     4     1  1551567600  1294059600
# 28                         cms     3    18  1551567600  1324213200
# 2                          ssl     3     8  1553554800  1372806000
# 12                   analytics     3     8  1553554800  1294059600
# 57                      mobile     3     2  1553554800  1415587208
# 34           wordpress-plugins     2     3  1551567600  1394409954
# 63                     hosting     2     3  1553554800  1345730400
# ...

# %%
##Drop Groups if needed.
data_filled_drop = data_filled.drop('groups', axis=1)
data_filled_drop
# Out:
#                           name  live  dead      latest      oldest  \
# 41                  javascript    10    35  1553554800  1304344800
# 80                          mx     5     3  1553554800  1315749600
# 23                   framework     5     2  1551567600  1378422000
# 72                         cdn     5     2  1553554800  1364302800
# 33                     widgets     4    18  1553554800  1294059600
# 61                  Web Server     4     4  1553554800  1294059600
# 73                       feeds     4     1  1551567600  1294059600
# 28                         cms     3    18  1551567600  1324213200
# 2                          ssl     3     8  1553554800  1372806000
# 12                   analytics     3     8  1553554800  1294059600
# 57                      mobile     3     2  1553554800  1415587208
# 34           wordpress-plugins     2     3  1551567600  1394409954
# 63                     hosting     2     3  1553554800  1345730400
# ...

# %%
#Export to CSV (or most any format)

#Data Filled with No Missing Values
data_filled.to_csv('BuiltWithAPIdataFILL.csv', index=False)
#Data Before Fill with Missing Values.
builtwith_API_final_df.to_csv('BuiltWithAPIdataNAN.csv', index=False)
#Data After Fill with Groups Drop
data_filled_drop.to_csv('BuiltWithAPIdataDROP.csv', index=False)
#Stock Data Clustered Group Values
bw_df_sort.to_csv('BuiltWithAPIdataGROUPS.csv', index=False)
#Groups Data Unclustered
test_API_df_first.to_csv('BuiltWithAPIdataRAW.csv', index=False)

# %% [markdown]
# ## Trial/Error Section(IGNORE)

# %%
#Trial/Error Section(IGNORE)

bw_API_group_df = builtwith_API_final_df.groupby('live')
bw_API_group_df.first()
# Out:
#                     name  dead      latest      oldest         first  \
# live
# 0     payment-acceptance     4  1492556400  1458738000  1.294060e+09
# 1          jquery-plugin     9  1551567600  1343570400  1.294060e+09
# 2      wordpress-plugins     3  1551567600  1394409954  1.294060e+09
# 3                    cms    18  1551567600  1324213200  1.294060e+09
# 4                widgets    18  1553554800  1294059600           NaN
# 5                     mx     3  1553554800  1315749600  1.294060e+09
# 10            javascript    35  1553554800  1304344800           NaN
#
#               last         domain  \
# live
# 0     1.553555e+09  builtwith.com
# 1     1.553555e+09  builtwith.com
# 2     1.553555e+09  builtwith.com
# 3     1.553555e+09  builtwith.com
# 4              NaN            NaN
# 5     1.553555e+09  builtwith.com
# 10             NaN            NaN
#
#                                                  groups
# live
# ...

# %%
#Trial/Error Section(IGNORE)
##format dataframe single row x columns (data = [{'x': y,'x1': y1,'x2': y2,'x3': y3,...}]
##format x rows x columns (data = [{'x': y,'x1': y1},{'z': 'n','z1' : 'n1'},...{}]
builtwith_domain_simple = [{'first': 1294059600,
 'last': 1553554800,
 'domain': 'builtwith.com',
    'live': 0,
     'dead': 1,
     'latest': 1476745200,
     'oldest': 1372806000,
     'name': 'wildcard'}]
builtwith_API_simple_df = pd.DataFrame.from_dict(builtwith_domain_simple, orient='columns')
builtwith_API_simple_df
# Out:
#    dead         domain       first        last      latest  live      name  \
# 0     1  builtwith.com  1294059600  1553554800  1476745200     0  wildcard
#
#        oldest
# 0  1372806000

# %%
builtwith_domain_df_trial = [{'first': 1294059600,
'last': 1553554800,
'domain': 'builtwith.com',
'groups': 'nan',
'name': 'payment'},
{'live': 0,
'dead': 5,
'latest': 1492556400,
'oldest': 1343570400,
'categories': 'nan',
'live': 0,
'dead': 1,
'latest': 1369922400,
'oldest': 1343570400},
{'name': 'payments-processor',
'live': 0,
'dead': 4,
'latest': 1492556400,
'oldest': 1458738000},
{'name': 'payment-acceptance',
'live': 1,
'dead': 1,
'latest': 1551567600,
'oldest': 1343570400},
{'name': 'retargeting-/-remarketing',
'live': 0,
'dead': 1,
'latest': 1369922400,
'oldest': 1343570400}]
builtwith_API_df_trial = pd.DataFrame.from_dict(builtwith_domain_df_trial, orient='columns')
builtwith_API_df_trial
# Out:
#   categories  dead         domain         first groups          last  \
# 0        NaN   NaN  builtwith.com  1.294060e+09    nan  1.553555e+09
# 1        nan   1.0            NaN           NaN    NaN           NaN
# 2        NaN   4.0            NaN           NaN    NaN           NaN
# 3        NaN   1.0            NaN           NaN    NaN           NaN
# 4        NaN   1.0            NaN           NaN    NaN           NaN
#
#          latest  live                       name        oldest
# 0           NaN   NaN                    payment           NaN
# 1  1.369922e+09   0.0                        NaN  1.343570e+09
# 2  1.492556e+09   0.0         payments-processor  1.458738e+09
# 3  1.551568e+09   1.0         payment-acceptance  1.343570e+09
# 4  1.369922e+09   0.0  retargeting-/-remarketing  1.343570e+09

# %%
#API Call Version 2(standard)
with urllib.request.urlopen("https://api.builtwith.com/free1/api.json?KEY=2cb7b958-c54c-465a-bd0e-a4e05774023e&LOOKUP=builtwith.com") as url:
    data = json.loads(url.read().decode())
    print(data)
# Out:
# {'first': 1294059600, 'last': 1553554800, 'domain': 'builtwith.com', 'groups': [{'name': 'payment', 'live': 0, 'dead': 5, 'latest': 1492556400, 'oldest': 1343570400, 'categories': [{'live': 0, 'dead': 1, 'latest': 1369922400, 'oldest': 1343570400, 'name': 'payments-processor'}, {'live': 0, 'dead': 4, 'latest': 1492556400, 'oldest': 1458738000, 'name': 'payment-acceptance'}]}, {'name': 'ssl', 'live': 3, 'dead': 8, 'latest': 1553554800, 'oldest': 1372806000, 'categories': [{'live': 0, 'dead': 1, 'latest': 1545951600, 'oldest': 1476831600, 'name': 'multi-domain'}, {'live': 1, 'dead': 1, 'latest': 1553554800, 'oldest': 1452303436, 'name': 'extended-validation'}, {'live': 1, 'dead': 4, 'latest': 1553554800, 'oldest': 1372806000, 'name': 'root-authority'}, {'live': 0, 'dead': 1, 'latest': 1476745200, 'oldest': 1372806000, 'name': 'wildcard'}]}, {'name': 'ads', 'live': 2, 'dead': 2, 'latest': 1551567600, 'oldest': 1343570400, 'categories': [{'live': 0, 'dead': 1, 'latest': 1348668000, 'olde
# ...

# %%
#API Call Version 3(overkill)
#Note:Call/Recieve content of URL parse it as JSON and return object.
try:
    from urllib.request import urlopen
except ImportError:
    from urllib2 import urlopen

def get_jsonparsed_data(url):
    response = urlopen(url)
    data = response.read().decode("utf-8")
    return json.loads(data)

url = ("https://api.builtwith.com/free1/api.json?KEY=2cb7b958-c54c-465a-bd0e-a4e05774023e&LOOKUP=builtwith.com")
print(get_jsonparsed_data(url))
# Out:
# {'first': 1294059600, 'last': 1553554800, 'domain': 'builtwith.com', 'groups': [{'name': 'payment', 'live': 0, 'dead': 5, 'latest': 1492556400, 'oldest': 1343570400, 'categories': [{'live': 0, 'dead': 1, 'latest': 1369922400, 'oldest': 1343570400, 'name': 'payments-processor'}, {'live': 0, 'dead': 4, 'latest': 1492556400, 'oldest': 1458738000, 'name': 'payment-acceptance'}]}, {'name': 'ssl', 'live': 3, 'dead': 8, 'latest': 1553554800, 'oldest': 1372806000, 'categories': [{'live': 0, 'dead': 1, 'latest': 1545951600, 'oldest': 1476831600, 'name': 'multi-domain'}, {'live': 1, 'dead': 1, 'latest': 1553554800, 'oldest': 1452303436, 'name': 'extended-validation'}, {'live': 1, 'dead': 4, 'latest': 1553554800, 'oldest': 1372806000, 'name': 'root-authority'}, {'live': 0, 'dead': 1, 'latest': 1476745200, 'oldest': 1372806000, 'name': 'wildcard'}]}, {'name': 'ads', 'live': 2, 'dead': 2, 'latest': 1551567600, 'oldest': 1343570400, 'categories': [{'live': 0, 'dead': 1, 'latest': 1348668000, 'olde
# ...
